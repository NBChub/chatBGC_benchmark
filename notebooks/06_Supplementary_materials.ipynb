# %%
import pandas as pd

# %%
df = pd.read_csv("2.Evaluated_benchmark_response.tsv", sep="\t", index_col=0)

# %%
df.columns
# Out:
# Index(['id', 'question', 'difficulty', 'category', 'label',
#        'answer_sql_expected', 'answer_summary_expected', 'answer_sql_LLM',
#        'answer_summary_LLM', 'model', 'llm_type', 'chatbgc_version',
#        'benchmark_version', 'sql_query_success', 'summary_evaluation',
#        'sql_evaluation', 'evaluator_model', 'summary_evaluation_reason',
#        'sql_evaluator_model'],
#       dtype='object')

# %%
df.loc[:, ["question", "difficulty", 'chatbgc_version',
       'benchmark_version', 'sql_query_success', 'summary_evaluation',
       'sql_evaluation', 'evaluator_model', 'summary_evaluation_reason',
       'sql_evaluator_model']]
# Out:
#                                                                                              question  \
# Q_03__openai_chat__gpt-3.5-turbo__RAG_benchmark...  List all regions with a best MIBiG hit descrip...
# Q_08__openai_chat__gpt-3.5-turbo__RAG_benchmark...  What are the different domain profiles availab...
# Q_22__openai_chat__gpt-3.5-turbo__RAG_benchmark...  Summarize the genus distribution in the antiSM...
# Q_25__openai_chat__gpt-3.5-turbo__RAG_benchmark...               Which regions has iterative modules?
# Q_34__openai_chat__gpt-3.5-turbo__RAG_benchmark...            Which PKS regions has trans_at modules?
# ...                                                                                               ...
# Q_34__ollama__llama3.1_8b__RAG_benchmark__itera...            Which PKS regions has trans_at modules?
# Q_34__ollama__mistral-nemo__RAG_benchmark__iter...            Which PKS regions has trans_at modules?
# ...
